# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('/content/titanic_train.xlsx')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.shape
# Out:
# (891, 12)

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data.drop(['PassengerId','Name','Ticket','Cabin'],axis =1,inplace = True)

# %%
data.shape
# Out:
# (891, 8)

# %%
data.duplicated().sum()
# Out:
# np.int64(111)

# %%
data.drop_duplicates(inplace = True)

# %%
data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         104
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %%
data.nunique()
# Out:
# Survived      2
# Pclass        3
# Sex           2
# Age          88
# SibSp         7
# Parch         7
# Fare        248
# Embarked      3
# dtype: int64

# %%
data['Age'].fillna(data['Age'].mean(),inplace = True)

# %%
data['Embarked'].fillna(data['Embarked'].mode()[0],inplace = True)

# %%
data.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 780 entries, 0 to 890
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  780 non-null    int64
#  1   Pclass    780 non-null    int64
#  2   Sex       780 non-null    object
#  3   Age       780 non-null    float64
#  4   SibSp     780 non-null    int64
#  5   Parch     780 non-null    int64
#  6   Fare      780 non-null    float64
#  7   Embarked  780 non-null    object
# dtypes: float64(2), int64(4), object(2)
# memory usage: 54.8+ KB

# %%
data.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  780.000000  780.000000  780.000000  780.000000  780.000000  780.000000
# mean     0.412821    2.246154   29.812751    0.525641    0.417949   34.829108
# std      0.492657    0.854452   13.708828    0.988046    0.838536   52.263440
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    1.000000   21.750000    0.000000    0.000000    8.050000
# 50%      0.000000    3.000000   29.812751    0.000000    0.000000   15.950000
# 75%      1.000000    3.000000   36.000000    1.000000    1.000000   34.375000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
plt.figure(figsize=(8,6))
sns.countplot(x =data['Survived'],data =data,palette ='hls')
plt.title('Survival Distribution')
plt.xlabel('Survived')
plt.ylabel('Frequency')
plt.show()

# %%
survived_counts = data['Survived'].value_counts()
plt.pie(survived_counts,labels = survived_counts.index,autopct='%1.1f%%',startangle=90)
plt.title('Survival Distribution')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize =(8,6))
sns.countplot(x = data['Pclass'],data=data,palette ='hls')
plt.title('Passenger Class Distribution')
plt.xlabel('Pclass')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize=(8, 5))
Pclass_counts = data['Pclass'].value_counts()
plt.pie(Pclass_counts,labels = Pclass_counts.index,autopct = '%1.1f%%',startangle =90)
plt.title('Passenger Class Distribution')
plt.xlabel('')
plt.ylabel('')
plt.show()

# %%
plt.figure(figsize =(8,6))
sns.countplot(x = data['Sex'],data =data,palette ='hls')
plt.title('Sex Distribution')
plt.xlabel('Sex')
plt.ylabel('count')
plt.show()

# %%
gender_count = data['Sex'].value_counts()
plt.figure(figsize =(8,5))
plt.pie(gender_count,labels = gender_count.index,autopct ='%1.1f%%',startangle =90)
plt.title('Sex Distribution')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(data['Age'],bins=10,color='skyblue',edgecolor='black')
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize =(8,6))
sns.boxplot(x = data['Age'],data = data,palette ='hls')
plt.title('Age Distribution')
plt.xlabel('Values')
plt.ylabel('Y')
plt.show()

# %%
plt.figure(figsize =(8,6))
plt.hist(data['Fare'],bins=10,color ='skyblue',edgecolor='black')
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize =(8,6))
sns.boxplot(x = data['Fare'],data = data,palette ='hls')
plt.title('Fare Distribution')
plt.xlabel('Values')
plt.ylabel('Y')
plt.show()

# %%
plt.figure(figsize =(8,6))
sns.countplot(x = data['Embarked'],data =data,palette ='hls')
plt.title('Embarked Distribution')
plt.xlabel('Embarked')
plt.ylabel('count')
plt.show()

# %%
plt.figure(figsize =(8,5))
Embarked_count = data['Embarked'].value_counts()
plt.pie(Embarked_count,labels = Embarked_count.index,autopct ='%1.1f%%',startangle =90)
plt.title('Embarked Distribution')
plt.show()

# %%
data = pd.get_dummies(data,columns=['Sex','Embarked'])

# %%
data
# Out:
#      Survived  Pclass        Age  SibSp  Parch     Fare  Sex_female  Sex_male  \
# 0           0       3  22.000000      1      0   7.2500       False      True
# 1           1       1  38.000000      1      0  71.2833        True     False
# 2           1       3  26.000000      0      0   7.9250        True     False
# 3           1       1  35.000000      1      0  53.1000        True     False
# 4           0       3  35.000000      0      0   8.0500       False      True
# ..        ...     ...        ...    ...    ...      ...         ...       ...
# 885         0       3  39.000000      0      5  29.1250        True     False
# 887         1       1  19.000000      0      0  30.0000        True     False
# 888         0       3  29.812751      1      2  23.4500        True     False
# 889         1       1  26.000000      0      0  30.0000       False      True
# 890         0       3  32.000000      0      0   7.7500       False      True
#
# ...

# %%
x = data.drop(['Survived'],axis =1)
y = data['Survived']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logireg = LogisticRegression()
logireg.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = logireg.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,confusion_matrix,classification_report,ConfusionMatrixDisplay

# %%
accuracy = accuracy_score(y_test,y_pred)
print(accuracy)

precision = precision_score(y_test,y_pred)
print(precision)

recall = recall_score(y_test,y_pred)
print(recall)

f1 = f1_score(y_test,y_pred)
print(f1)

cm = confusion_matrix(y_test, y_pred)
print(cm)

y_prob = logireg.predict_proba(x_test)

cr = classification_report(y_test, y_pred)
print(cr)
# Out:
# 0.782051282051282
# 0.7627118644067796
# 0.6923076923076923
# 0.7258064516129032
# [[77 14]
#  [20 45]]
#               precision    recall  f1-score   support
#
#            0       0.79      0.85      0.82        91
#            1       0.76      0.69      0.73        65
#
#     accuracy                           0.78       156
#    macro avg       0.78      0.77      0.77       156
# weighted avg       0.78      0.78      0.78       156

# %%
disp = ConfusionMatrixDisplay(confusion_matrix = cm,display_labels = logireg.classes_)
disp.plot(cmap = plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()
